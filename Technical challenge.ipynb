# %%
 #Importing Necessary Modules
#--------------------------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') 
from sklearn.model_selection import train_test_split

# %%
import os

# Get the current working directory
cwd = os.getcwd()

# %%
cwd
# Out:
# '/Users/Kumar/Desktop/data-analytics-challenge'

# %%
# Loading the data
#-------------------------------------
df = pd.read_csv('/Users/Kumar/Desktop/data-analytics-challenge/measurements.csv')
df.head()
# Out:
#   distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0       28       5     26        21,5            12      NaN      E10   0
# 1       12     4,2     30        21,5            13      NaN      E10   0
# 2     11,2     5,5     38        21,5            15      NaN      E10   0
# 3     12,9     3,9     36        21,5            14      NaN      E10   0
# 4     18,5     4,5     46        21,5            15      NaN      E10   0
#
#    rain  sun refill liters refill gas
# 0     0    0            45        E10
# 1     0    0           NaN        NaN
# 2     0    0           NaN        NaN
# 3     0    0           NaN        NaN
# 4     0    0           NaN        NaN

# %%
df
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0         28       5     26        21,5            12      NaN      E10   0
# 1         12     4,2     30        21,5            13      NaN      E10   0
# 2       11,2     5,5     38        21,5            15      NaN      E10   0
# 3       12,9     3,9     36        21,5            14      NaN      E10   0
# 4       18,5     4,5     46        21,5            15      NaN      E10   0
# ..       ...     ...    ...         ...           ...      ...      ...  ..
# 383       16     3,7     39        24,5            18      NaN     SP98   0
# 384     16,1     4,3     38          25            31       AC     SP98   1
# 385       16     3,8     45          25            19      NaN     SP98   0
# 386     15,4     4,6     42          25            31       AC     SP98   1
# 387     14,7       5     25          25            30       AC     SP98   1
#
#      rain  sun refill liters refill gas
# ...

# %%
#we neeed to replace the , value to . in the distance ,consume, and temp_inside columns
#to do that lets seperate the numerical columns and categorical columns
# alternative way
df.select_dtypes(['number'])
# Out:
#      speed  temp_outside  AC  rain  sun
# 0       26            12   0     0    0
# 1       30            13   0     0    0
# 2       38            15   0     0    0
# 3       36            14   0     0    0
# 4       46            15   0     0    0
# ..     ...           ...  ..   ...  ...
# 383     39            18   0     0    0
# 384     38            31   1     0    0
# 385     45            19   0     0    0
# 386     42            31   1     0    0
# 387     25            30   1     0    0
#
# [388 rows x 5 columns]

# %%
df
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0         28       5     26        21,5            12      NaN      E10   0
# 1         12     4,2     30        21,5            13      NaN      E10   0
# 2       11,2     5,5     38        21,5            15      NaN      E10   0
# 3       12,9     3,9     36        21,5            14      NaN      E10   0
# 4       18,5     4,5     46        21,5            15      NaN      E10   0
# ..       ...     ...    ...         ...           ...      ...      ...  ..
# 383       16     3,7     39        24,5            18      NaN     SP98   0
# 384     16,1     4,3     38          25            31       AC     SP98   1
# 385       16     3,8     45          25            19      NaN     SP98   0
# 386     15,4     4,6     42          25            31       AC     SP98   1
# 387     14,7       5     25          25            30       AC     SP98   1
#
#      rain  sun refill liters refill gas
# ...

# %%
df.loc[[df['distance'] == ',',"distance"] = .
# Out:
#   File "/var/folders/_n/wzm_vp5d0rd989db9nyndr8m0000gp/T/ipykernel_33001/2435467049.py", line 1
#     df.loc[[df['distance'] == ',',"distance"] = .
#                                               ^
# SyntaxError: invalid syntax
